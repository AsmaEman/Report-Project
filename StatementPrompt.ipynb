# %%
# !pip install langchain openai
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 809.1/809.1 kB 4.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 221.4/221.4 kB 23.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 25.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 189.1/189.1 kB 21.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.2/48.2 kB 6.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.0/75.0 kB 5.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 6.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.9/76.9 kB 9.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 7.6 MB/s eta 0:00:00
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# llmx 0.0.15a0 requires cohere, which is not installed.
# ...

# %%
prompt = """Answer the question based on the context below. If the
question cannot be answered using the information provided answer
with "I don't know".

Context:General Information
Report Number

R12345
Report Date

2023/12/12
Report Officer

Smith
Assignment

Assault Investigation
Incident Details
Incident Date

2023/12/12
Incident Location

Main Street
Incident Nature

Assault
Injuries Observed

Bruises on victim's face
Initial Observation

Police received a distress call at 21:30 reporting an assault in progress.
Victim Information
Victim Name

Jane Doe
Victim Address

123 Street
Victim Conatct (Email / Phone)

jane.doe@email.com / 555-1234
Victim's Statement

I was walking home when the attacker approached me from behind.
Witness Information
Witness Name

John Smith
Witness Address

456  Avenue
Witness Conatct (Email / Phone)

john.smith@email.com / 555-5678
Relationship to Victim

Neighbor
Witness's Statement

I heard screams and saw the incident from my window.
Suspect Information
Suspect's Name

Unknown
Suspect Description

Male, 6 feet tall, wearing a black hoodie
Suspect's Current Location

Not known
Evidence Collected
Photographs / Reports / Footage

Drag and drop file here
Limit 200MB per file
Details of Evidence

Security camera footage, victim's statement, witness statement
Investigation Summary
Crime Scene

Main Street, near the park
Suspect's Background Check

Pending
Other Actions

Interviewed witnesses, collected evidence
Final Remarks
Additional Observations

Incident occurred at a poorly lit area.
Reporting Officer's Statement

This case requires further investigation.
Case Status

Pending
Report Completion Date

2023/12/12
Review Date

2023/12/12


Question:  Generate a detailed Reporting Officer's Statement based on the provided incident report. The template includes placeholders for specific details. Please replace these placeholders with relevant information from the incident report. Ensure that the generated statement provides a coherent and detailed perspective from the reporting officer regarding the investigation?

Answer: """

# %%
from langchain.llms import OpenAI

# initialize the models
openai = OpenAI(
    model_name="text-davinci-003",
    openai_api_key=""
)

# %%
print(openai(prompt))
# Out:
#  Based on the incident report, I, Officer Smith, concluded that an assault had occurred on Main Street near the park on 2023/12/12 at 21:30. The victim, Jane Doe, reported that the attacker approached her from behind. The witness, John Smith, reported that he heard screams and saw the incident from his window. The suspect is described as a male, 6 feet tall, wearing a black hoodie. The evidence collected included security camera footage, victim's statement, and witness statement. The incident occurred in a poorly lit area. This case requires further investigation. The case status is pending and the review date is 2023/12/12.
